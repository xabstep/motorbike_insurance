# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from datetime import datetime
import time
import re
import random
import string

# %% [markdown]
# # Accessing to the website

# %%
driver = webdriver.Firefox()
driver.get('https://seguro-moto.rastreator.com/datos-comparativa/Q1')
time.sleep(5)
button_cookies = driver.find_element_by_xpath("/html/body/div[4]/div/div[2]/button[2]")
time.sleep(3)
button_cookies.click()

# %% [markdown]
# # Scrapping

# %%
bbdd_moto = []
count = 1

#list_marcas = driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-make/div/div/div/ul[1]').text.split("\n")
list_marcas = ['YAMAHA']


for marca in list_marcas:  
    print(f'_________________________\n{marca} ({count}/{len(list_marcas)})\n--------------------------')
    path_marca = f'//*[@id="li_top_{marca}"]'
    button_marca = driver.find_element_by_xpath(path_marca)
    button_marca.click()
    time.sleep(2)
    list_usados = driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-model/div/div[2]/div/ul[1]').text.split("\n")
    counter = 1
    for modelo in list_usados:
        print(f'- {modelo}, {counter}/{len(list_usados)}')
        counter+=1
        button_modelo = driver.find_element_by_xpath(f'//*[@id="li_{modelo}"]')
        button_modelo.click()
        time.sleep(2)
        page = driver.current_url[-2:]
        if page == 'Q3':
            lista_cc = driver.find_element_by_xpath('//*[@id="card"]').text.split('\n')
            for j in range(3,len(lista_cc)-1):
                button_cc = driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-cubic-capacity/div/div[{j}]')
                button_cc.click()
                cilindr = int(lista_cc[j].split(' ')[0])
                time.sleep(2)
                page = driver.current_url[-2:]
                if page == 'Q4' and cilindr <= 125 and cilindr > 0:
                    modelo_lanz = driver.find_element_by_xpath('//*[@id="questionContainer"]').text.split('\n')
                    k = 1
                    pg = 1
                    while k < len(modelo_lanz) and int(modelo_lanz[k+1][-4:]) >= 2018:
                        #bbdd_moto.append([marca, modelo, lista_cc[j], modelo_lanz[k], modelo_lanz[k+1]])
                        lista_it = [marca, modelo, lista_cc[j], modelo_lanz[k], modelo_lanz[k+1].split(' | ')[1], int(modelo_lanz[k+1][-4:])]
                        time.sleep(2)
                        driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-version/div/div[{pg}]/label/div/span').click()
                        time.sleep(2)
                        driver.find_element_by_xpath("/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-already-bought/div/div[1]/label/div/span").click()
                        time.sleep(2)
                            
                        for year_old in [0]:
                            year_old_new = lista_it[5]+year_old
                            if year_old_new > 2021:
                                pass
                            else:
                                for year_mat in [0,2]:
                                    year_mat_new = lista_it[5]+year_mat
                                    if year_mat_new > 2021:
                                        pass
                                    else:
                                        if year_old>year_mat:
                                            pass
                                        else:
                                            select_monthOld = Select(driver.find_element_by_id('monthOld'))
                                            select_monthOld.select_by_visible_text('Junio')
                                            
                                            select_buyMonth = Select(driver.find_element_by_id('buyMonth'))
                                            select_buyMonth.select_by_visible_text('Junio')
                                            
                                            select_yearOld = Select(driver.find_element_by_id('yearOld'))
                                            select_yearOld.select_by_visible_text(f'{year_old_new}')
                                            
                                            select_buyYear = Select(driver.find_element_by_id('buyYear'))
                                            
                                            select_buyYear.select_by_visible_text(f'{year_mat_new}')
                                            lista_year = lista_it+[year_mat_new]
                                            
                                            time.sleep(2)
                                            
                                            driver.find_element_by_xpath('//*[@id="next"]').click()
                                            time.sleep(2)
                                            driver.find_element_by_xpath("/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-bike-usage/div/div[2]/label/div/span").click()
                                            time.sleep(2)
                                            driver.find_element_by_xpath("/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-passenger-type/div/div[3]/label/div/span").click()
                                            time.sleep(2)
                                            driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-parking-type/div/div[2]/label/div').click()
                                            time.sleep(2)
                                            kms = driver.find_element_by_xpath('//*[@id="questionContainer"]').text.split('\n')
                                            #for km in range(2,len(kms),3):
                                            for km in [6]:
                                                #lista_km = []
                                                #lista_km = lista_year+[driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-annual-km/div/div[{km}]/label/div/span').text]
                                                driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-annual-km/div/div[{km}]/label/div/span').click()
                                                time.sleep(2)
                                                                                     
                                                for year_birth in ['2002', '1999', '1995']:
                                                    driver.refresh()
                                                    time.sleep(3)
                                                    
                                                    input_day = driver.find_element_by_xpath('//*[@id="day"]')
                                                    input_day.clear()
                                                    input_day.send_keys('06')
                                                    time.sleep(2)
                                                    
                                                    select_month = Select(driver.find_element_by_xpath('//*[@id="month"]'))
                                                    select_month.select_by_visible_text('Junio')
                                                    time.sleep(2)
                                                    
                                                    input_year = driver.find_element_by_xpath('//*[@id="year"]')
                                                    input_year.clear()
                                                    input_year.send_keys(year_birth)
                                                    time.sleep(2)
                                                    lista_birth = []
                                                    lista_birth = lista_year + [2021-int(year_birth)]
                                                    #lista_birth = lista_km + [2021-int(year_birth)]
                                                    driver.find_element_by_xpath('//*[@id="next"]').click()
                                                    time.sleep(2)
                                                    driver.find_element_by_xpath("/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-birth-place/div/div/div[1]/div/label/div/div/img").click()
                                                    time.sleep(2)
                                                    #for gen in range(1,3):
                                                    for gen in [1]:
                                                        genero = driver.find_element_by_xpath(f"/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-main-driver-data/div/div[2]/div[{gen}]/div/label/div/p")
                                                        #lista_gen = []
                                                        #lista_gen = lista_birth + [genero.text]
                                                        genero.click()
                                                        time.sleep(2)
                                                        try:
                                                            driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-main-driver-data/div/div[4]/div/div[1]/label/div/span').click()
                                                        except:
                                                            pass
                                                        time.sleep(2)
                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-profession/div/div[18]/label/div/span').click()
                                                        time.sleep(2)
                                                        
                                                        #for cp in range(1,53):
                                                        for cp in [8,28]:
                                                            if cp < 10:
                                                                postcode = f'0{cp}001'
                                                            else:
                                                                postcode = f'{cp}001'
                                                            input_cp = driver.find_element_by_id("postalCode")
                                                            input_cp.clear()
                                                            input_cp.send_keys(postcode)
                                                            lista_cp = []
                                                            lista_cp = lista_birth + [str(postcode)]
                                                            time.sleep(2)
                                                        
                                                            driver.find_element_by_xpath('//*[@id="next"]').click()
                                                            time.sleep(2)
                                                            driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/app-bike-driver-childs/div/div/div/div[2]/label/div/span').click()
                                                            time.sleep(2)
                                                            
                                                            lista_c = driver.find_element_by_xpath('//*[@id="questionContainer"]').text.split('\n')[2:]
                                                            for carn in range(2,len(lista_c)+2):
                                                                
                                                                carnet = driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-licence-type/div/div[{carn}]/label/div/span')
                                                                lista_carnet = []
                                                                lista_carnet = lista_cp + [carnet.text]
                                                                
                                                                    
                                                                if carnet.text == 'B (carné de coche)':
                                                                    pass
                                                                
                                                                else:
                                                                    if year_birth == '2002':
                                                                        obt_carnet = ['2021']
                                                                    elif year_birth == '1999':
                                                                        obt_carnet = ['2021','2018']
                                                                    else:
                                                                        obt_carnet = ['2021','2018','2014']    
                                                                    
                                                                    carnet.click()
                                                                    time.sleep(2)
                                                                    
                                                                    for year_carn in obt_carnet:
                                                                        
                                                                        driver.refresh()
                                                                        time.sleep(5)
                                                                        
                                                                        select_month = Select(driver.find_element_by_xpath('//*[@id="year"]'))
                                                                        select_month.select_by_visible_text(year_carn)
                                                                        time.sleep(2)
                                                                        
                                                                        select_month = Select(driver.find_element_by_xpath('//*[@id="month"]'))
                                                                        select_month.select_by_visible_text('Julio')
                                                                        time.sleep(2)
                                                                        
                                                                        lista_obt = []
                                                                        lista_obt = lista_carnet + [int(year_carn)-int(year_birth)]
                                                                        page_input = driver.current_url
                                                                        
                                                                        driver.find_element_by_xpath('//*[@id="next"]').click()
                                                                        time.sleep(2)
                                                                        driver.refresh()
                                                                        time.sleep(3)
                                                                        
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-licence-place/div/div/div[1]/div/label/div/p').click()
                                                                        time.sleep(2)
                                                                        try:
                                                                            driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/app-last-bike/div/div/div/div[1]/label/div/span').click()
                                                                        except:
                                                                            pass
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-who-policy-holder/div/div[1]/label/div/span').click()
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/app-defaulter/div/div[2]/label/div/span').click()
                                                                        driver.refresh()
                                                                        time.sleep(5)
                                                        
                                                                        input_dni = driver.find_element_by_xpath('//*[@id="txtDniNumber"]')
                                                                        input_dni.clear()
                                                                        input_dni.send_keys('73115063H')
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('//*[@id="next"]').click()
                                                                        
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-insurer-name/div/div[1]/div/div[2]/label/div/span/font/font').click()
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/app-has-claim/div/div[2]/div/div[2]/label/div/span').click()
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-previous-fine/div/div[2]/div/div[2]/label/div/span').click()
                                                                        time.sleep(2)
                                                                        select_month = Select(driver.find_element_by_xpath('//*[@id="day"]'))
                                                                        select_month.select_by_visible_text('1')
                                                                        time.sleep(2)
                                                                        select_month = Select(driver.find_element_by_xpath('//*[@id="month"]'))
                                                                        select_month.select_by_visible_text('Septiembre')
                                                                        time.sleep(2)
                                                                        select_month = Select(driver.find_element_by_xpath('//*[@id="year"]'))
                                                                        select_month.select_by_visible_text('2021')
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('//*[@id="next"]').click()
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-kind-of-insurance/div/div[5]/label/div/span').click()
                                                                        driver.refresh()
                                                                        time.sleep(5)
                                                        
                                                                        input_mail = driver.find_element_by_xpath('//*[@id="email"]')
                                                                        input_mail.clear()
                                                                        input_mail.send_keys('xabilopez8@hotmail.com')
                                                                        time.sleep(2)
                                                                        input_phone = driver.find_element_by_xpath('//*[@id="phone"]')
                                                                        input_phone.clear()
                                                                        input_phone.send_keys('606697311')
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath("/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-email-info/div/div[3]/label/div/span[1]").click()
                                                                        
                                                                        rastreator_last = driver.current_url
                                                                        
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-email-info/app-nav-option/a[2]/font/font').click()
                                                                                                                                   
                                                                        time.sleep(30)
                                                                        while driver.current_url == 'https://presupuesto-moto.rastreator.com/resultados-comparativa/isWaitPageCounterInserted':
                                                                            time.sleep(2)
                                                                            driver.refresh()
                                                                        time.sleep(2)
                                                                        
                                                                        try:
                                                                            insur = driver.find_element_by_xpath('/html/body/app-root/div[1]/app-quote-page/div/div/div[1]/filter/div/div').text.split('\n')
                                                                            for ins in range(0,len(insur),3):
                                                                                insurance = insur[ins]
                                                                                precio = str(insur[ins+2].split('desde')[1])
                                                                                lista_ins = [] 
                                                                                lista_ins = lista_obt + [insurance] + [precio]
                                                                                bbdd_moto.append(lista_ins)
                                                                                #df = pd.DataFrame(bbdd_moto, columns = ['Marca','Modelo','Cilindrada','Versión','Potencia','Año lanzamiento','Año matriculación','Año compra','KM esperados','Edad','Género','Código postal','Tipo carnet','Años carnet','Tipo seguro','Precio mínimo'])
                                                                                df = pd.DataFrame(bbdd_moto, columns = ['Marca','Modelo','Cilindrada','Versión','Potencia','Año lanzamiento','Año matriculación','Edad actual','Código postal','Tipo carnet','Edad carnet','Tipo seguro','Precio mínimo'])
                                                                                df.to_csv('../data/dataset_yamaha.csv', index=False)
                                                                                print(lista_ins)
                                                                        except:
                                                                            pass
                                                                        
                                                                        while driver.current_url[:-2] != 'https://seguro-moto.rastreator.com/datos-comparativa/Q':
                                                                            driver.back()
                                                                            #time.sleep(0.5)
                                                                        driver.refresh()
                                                                        time.sleep(3)
                                                                        while driver.current_url[:-2] != 'https://seguro-moto.rastreator.com/datos-comparativa/Q':
                                                                            driver.back()
                                                                        driver.refresh()
                                                                        time.sleep(10)
                                                                        while page_input != driver.current_url:
                                                                            driver.back()
                                                                            time.sleep(3)
                                                                        driver.refresh()
                                                                        time.sleep(5)
                                                                    
                                                                    driver.back()
                                                                    time.sleep(2)
                                                            driver.back()
                                                            time.sleep(2)
                                                            driver.back()
                                                            time.sleep(2)
                           
                        
                                                        driver.back()
                                                        time.sleep(2)
                                
                        
                                                        driver.back()
                                                        time.sleep(2)
                                                    driver.back()
                                                    time.sleep(2)
                                                    driver.back()
                                                    time.sleep(2)
                                                driver.back()
                                                time.sleep(2)
                                            driver.back()
                                            time.sleep(2)
                                            driver.back()
                                            time.sleep(2)
                                            driver.back()
                                            time.sleep(2)
                                            driver.back()
                                            time.sleep(2)
                                            
                        driver.back()
                        time.sleep(2)
                        driver.back()
                        time.sleep(2)
                        pg += 1
                        k+=2
                        
                else:
                    pass
                driver.back()
                time.sleep(2)  
        else:
            pass
        driver.back()
        time.sleep(2)
    driver.back()
    time.sleep(2)
    count += 1
# Out:
# _________________________
# YAMAHA (1/1)
# --------------------------
# - AEROX 50, 1/60
# - BW S 125, 2/60
# - DELIGHT, 3/60
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '331€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '348€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '624€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '1.127€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '279€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '296€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '526€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '957€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '264€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '281€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '499€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '896€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '223€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '240€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '422€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '762€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '250€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '267€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '473€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Todo riesgo con franquicia', '911€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '177€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '194€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '335€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '569€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '225€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '242€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '426€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Todo riesgo con franquicia', '773€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '156€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '173€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '296€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '519€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '200€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '217€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '380€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Todo riesgo con franquicia', '726€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '142€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '159€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '271€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '455€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '180€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '198€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '342€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Todo riesgo con franquicia', '617€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '126€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '143€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '240€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '416€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '201€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '218€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '345€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Todo riesgo con franquicia', '717€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '145€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '162€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '251€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Todo riesgo con franquicia', '359€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '111€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '128€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '213€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '357€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '181€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '198€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '344€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Todo riesgo con franquicia', '649€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '129€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '146€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '246€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Todo riesgo con franquicia', '359€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '100€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '117€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '191€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '323€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '161€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '178€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '306€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Todo riesgo con franquicia', '573€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '117€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '134€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '224€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Todo riesgo con franquicia', '359€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '91€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '108€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '175€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '288€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '146€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '163€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '278€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Todo riesgo con franquicia', '519€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '105€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '122€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '201€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Todo riesgo con franquicia', '329€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '81€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '99€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '158€']
# ['YAMAHA', 'DELIGHT', '125 cc', 'DELIGHT 125', '8 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '261€']
# - EC-03, 4/60
# - FJR 1300, 5/60
# - FZ8, 6/60
# - GIGGLE, 7/60
# - GRIZZLY, 8/60
# - GRIZZLY 700, 9/60
# - GRYZZLY 300, 10/60
# - KODIAK 450, 11/60
# - KODIAK 700, 12/60
# - MAJESTY 125, 13/60
# - MT, 14/60
# - MT 03, 15/60
# - MT 07, 16/60
# - MT 09, 17/60
# - MT 10, 18/60
# - MT 125, 19/60
# - NEOS 50, 20/60
# - NIKEN, 21/60
# - NMAX, 22/60
# - R 125, 23/60
# - R1, 24/60
# - R1, 25/60
# - R3, 26/60
# - R6, 27/60
# - R6, 28/60
# - SCR, 29/60
# - SR 400, 30/60
# - STRYKER, 31/60
# - TENERE, 32/60
# - T-MAX, 33/60
# - T-MAX, 34/60
# - TRACER, 35/60
# - TRICITY, 36/60
# - TT-R110, 37/60
# - TT-R50, 38/60
# - TZR 50, 39/60
# - X-ENTER, 40/60
# - XJ6, 41/60
# - XJR 1300, 42/60
# - X-MAX, 43/60
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '373€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '390€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '702€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '1.322€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '314€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '331€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '592€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '1.122€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '297€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '314€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '560€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '1.050€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '250€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '268€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '473€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '892€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '282€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '299€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '531€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Todo riesgo con franquicia', '1.068€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '198€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '215€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '375€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '665€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '253€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '270€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '478€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Todo riesgo con franquicia', '905€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '174€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '191€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '331€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '605€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '225€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '242€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '426€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Todo riesgo con franquicia', '849€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '159€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '176€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '303€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '531€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '203€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '220€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '384€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Todo riesgo con franquicia', '721€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '140€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '157€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '268€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '484€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '225€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '242€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '390€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Todo riesgo con franquicia', '839€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '159€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '176€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '296€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Todo riesgo con franquicia', '489€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '124€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '141€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '237€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '415€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '203€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '220€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '385€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Todo riesgo con franquicia', '759€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '144€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '161€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '275€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Todo riesgo con franquicia', '475€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '111€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '128€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '213€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '375€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '181€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '198€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '302€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Todo riesgo con franquicia', '669€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '131€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '148€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '250€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Todo riesgo con franquicia', '429€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '101€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '118€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '194€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '334€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '163€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '180€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '302€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Todo riesgo con franquicia', '606€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '117€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '134€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '223€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Todo riesgo con franquicia', '381€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '90€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '108€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '174€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125', '12 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '302€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '373€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '390€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '736€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '1.397€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '314€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '331€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '620€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '1.185€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '297€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '314€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '587€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '1.108€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '250€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '268€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '495€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '941€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '282€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '299€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '556€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Todo riesgo con franquicia', '1.128€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '198€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '215€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '393€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '701€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '253€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '270€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '500€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Todo riesgo con franquicia', '956€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '174€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '191€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '346€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '639€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '225€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '242€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '445€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Todo riesgo con franquicia', '896€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '159€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '176€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '316€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '560€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '203€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '220€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '401€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Todo riesgo con franquicia', '760€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '140€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '157€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '279€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '510€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '225€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '242€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '398€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Todo riesgo con franquicia', '886€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '159€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '176€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '304€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Todo riesgo con franquicia', '513€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '124€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '141€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '248€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '437€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '203€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '220€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '398€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Todo riesgo con franquicia', '801€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '144€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '161€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '287€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Todo riesgo con franquicia', '501€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '111€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '128€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '222€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '395€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '181€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '198€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '303€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 TECH MAX', '12 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Todo riesgo con franquicia', '706€']
# ...
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '262€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '279€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '519€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '987€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '295€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '312€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '583€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Todo riesgo con franquicia', '1.183€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '207€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '224€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '394€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '735€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '265€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '282€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '524€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Todo riesgo con franquicia', '1.002€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '182€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '199€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '362€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '669€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '236€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '253€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '466€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Todo riesgo con franquicia', '940€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '166€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '184€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '331€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '586€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '212€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '229€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '420€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Todo riesgo con franquicia', '797€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '147€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '164€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '292€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '534€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '236€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '253€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '394€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Todo riesgo con franquicia', '929€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '159€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '176€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '300€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Todo riesgo con franquicia', '592€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '130€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '147€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '259€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '406€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '213€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '230€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '394€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Todo riesgo con franquicia', '840€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '151€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '168€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '300€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Todo riesgo con franquicia', '524€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '116€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '133€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '231€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '413€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '183€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '206€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '307€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Todo riesgo con franquicia', '739€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '137€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '154€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '272€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Todo riesgo con franquicia', '473€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '105€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '122€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '211€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '367€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '171€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '188€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '307€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Todo riesgo con franquicia', '669€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '122€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '139€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '243€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Todo riesgo con franquicia', '420€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '94€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '111€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '189€']
# ['YAMAHA', 'X-MAX', '125 cc', 'X-MAX 125 IRON MAX ABS', '14 CV', 2018, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '332€']
# - XP 500, 44/60
# - XSR, 45/60
# - XT 1200, 46/60
# - XT 660, 47/60
# - XV 950, 48/60
# - YBR 125, 49/60
# - YFM 700, 50/60
# - YFM 90, 51/60
# - YFZ 450, 52/60
# - YFZ 50, 53/60
# - YS, 54/60
# - YZ 250, 55/60
# - YZ 85, 56/60
# - YZF R, 57/60
# - YZF R1, 58/60
# - YZF R3, 59/60
# - YZF R6, 60/60

# %%
df
# Out:
#       Marca   Modelo Cilindrada                 Versión Potencia  \
# 0    YAMAHA  DELIGHT     125 cc             DELIGHT 125     8 CV
# 1    YAMAHA  DELIGHT     125 cc             DELIGHT 125     8 CV
# 2    YAMAHA  DELIGHT     125 cc             DELIGHT 125     8 CV
# 3    YAMAHA  DELIGHT     125 cc             DELIGHT 125     8 CV
# 4    YAMAHA  DELIGHT     125 cc             DELIGHT 125     8 CV
# ..      ...      ...        ...                     ...      ...
# 571  YAMAHA    X-MAX     125 cc  X-MAX 125 IRON MAX ABS    14 CV
# 572  YAMAHA    X-MAX     125 cc  X-MAX 125 IRON MAX ABS    14 CV
# 573  YAMAHA    X-MAX     125 cc  X-MAX 125 IRON MAX ABS    14 CV
# 574  YAMAHA    X-MAX     125 cc  X-MAX 125 IRON MAX ABS    14 CV
# 575  YAMAHA    X-MAX     125 cc  X-MAX 125 IRON MAX ABS    14 CV
#
#      Año lanzamiento  Año matriculación  Edad actual Código postal  \
# 0               2021               2021           19         08001
# 1               2021               2021           19         08001
# 2               2021               2021           19         08001
# 3               2021               2021           19         08001
# 4               2021               2021           19         08001
# ..               ...                ...          ...           ...
# 571             2018               2020           26         28001
# 572             2018               2020           26         28001
# 573             2018               2020           26         28001
# 574             2018               2020           26         28001
# 575             2018               2020           26         28001
#
#                                            Tipo carnet  Edad carnet  \
# 0              A1 (para conducir motos de hasta 125cc)           19
# 1              A1 (para conducir motos de hasta 125cc)           19
# 2              A1 (para conducir motos de hasta 125cc)           19
# 3              A1 (para conducir motos de hasta 125cc)           19
# 4    A2 (para motos de hasta 35kw y 0,2 kw/kg o mot...           19
# ..                                                 ...          ...
# 571  A2 (para motos de hasta 35kw y 0,2 kw/kg o mot...           23
# 572  A2 (para motos de hasta 35kw y 0,2 kw/kg o mot...           19
# 573  A2 (para motos de hasta 35kw y 0,2 kw/kg o mot...           19
# 574  A2 (para motos de hasta 35kw y 0,2 kw/kg o mot...           19
# 575  A2 (para motos de hasta 35kw y 0,2 kw/kg o mot...           19
#
#                           Tipo seguro Precio mínimo
# 0    Terceros sin asistencia en viaje          331€
# 1    Terceros con asistencia en viaje          348€
# 2                   Terceros ampliado          624€
# 3          Todo riesgo con franquicia        1.127€
# 4    Terceros sin asistencia en viaje          279€
# ..                                ...           ...
# 571        Todo riesgo con franquicia          420€
# 572  Terceros sin asistencia en viaje           94€
# 573  Terceros con asistencia en viaje          111€
# 574                 Terceros ampliado          189€
# 575        Todo riesgo con franquicia          332€
#
# [576 rows x 13 columns]

# %%
df[['Marca','Modelo','Cilindrada','Versión','Año matriculación']].groupby(['Marca','Modelo','Versión','Año matriculación']).agg(['count'])
# Out:
#                                                         Cilindrada
#                                                              count
# Marca  Modelo  Versión                Año matriculación
# YAMAHA DELIGHT DELIGHT 125            2021                      96
#        X-MAX   X-MAX 125              2021                      96
#                X-MAX 125 IRON MAX ABS 2018                      96
#                                       2020                      96
#                X-MAX 125 TECH MAX     2021                      96
#                X-MAX 125 TECH MAX ABS 2020                      96
