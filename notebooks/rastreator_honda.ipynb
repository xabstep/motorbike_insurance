# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from datetime import datetime
import time
import re
import random
import string

# %% [markdown]
# # Accessing to the website

# %%
driver = webdriver.Firefox()
driver.get('https://seguro-moto.rastreator.com/datos-comparativa/Q1')
time.sleep(5)
button_cookies = driver.find_element_by_xpath("/html/body/div[4]/div/div[2]/button[2]")
time.sleep(3)
button_cookies.click()

# %% [markdown]
# # Scrapping

# %%
bbdd_moto = []
count = 1

#list_marcas = driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-make/div/div/div/ul[1]').text.split("\n")
list_marcas = ['HONDA']


for marca in list_marcas:  
    print(f'_________________________\n{marca} ({count}/{len(list_marcas)})\n--------------------------')
    path_marca = f'//*[@id="li_top_{marca}"]'
    button_marca = driver.find_element_by_xpath(path_marca)
    button_marca.click()
    time.sleep(2)
    list_usados = driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-model/div/div[2]/div/ul[1]').text.split("\n")
    counter = 1
    for modelo in list_usados:
        print(f'- {modelo}, {counter}/{len(list_usados)}')
        counter+=1
        button_modelo = driver.find_element_by_xpath(f'//*[@id="li_{modelo}"]')
        button_modelo.click()
        time.sleep(2)
        page = driver.current_url[-2:]
        if page == 'Q3':
            lista_cc = driver.find_element_by_xpath('//*[@id="card"]').text.split('\n')
            for j in range(3,len(lista_cc)-1):
                button_cc = driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-cubic-capacity/div/div[{j}]')
                button_cc.click()
                cilindr = int(lista_cc[j].split(' ')[0])
                time.sleep(2)
                page = driver.current_url[-2:]
                if page == 'Q4' and cilindr <= 125 and cilindr > 0:
                    modelo_lanz = driver.find_element_by_xpath('//*[@id="questionContainer"]').text.split('\n')
                    k = 1
                    pg = 1
                    while k < len(modelo_lanz) and int(modelo_lanz[k+1][-4:]) >= 2018:
                        #bbdd_moto.append([marca, modelo, lista_cc[j], modelo_lanz[k], modelo_lanz[k+1]])
                        lista_it = [marca, modelo, lista_cc[j], modelo_lanz[k], modelo_lanz[k+1].split(' | ')[1], int(modelo_lanz[k+1][-4:])]
                        time.sleep(2)
                        driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-version/div/div[{pg}]/label/div/span').click()
                        time.sleep(2)
                        driver.find_element_by_xpath("/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-already-bought/div/div[1]/label/div/span").click()
                        time.sleep(2)
                            
                        for year_old in [0]:
                            year_old_new = lista_it[5]+year_old
                            if year_old_new > 2021:
                                pass
                            else:
                                for year_mat in [0,2]:
                                    year_mat_new = lista_it[5]+year_mat
                                    if year_mat_new > 2021:
                                        pass
                                    else:
                                        if year_old>year_mat:
                                            pass
                                        else:
                                            select_monthOld = Select(driver.find_element_by_id('monthOld'))
                                            select_monthOld.select_by_visible_text('Junio')
                                            
                                            select_buyMonth = Select(driver.find_element_by_id('buyMonth'))
                                            select_buyMonth.select_by_visible_text('Junio')
                                            
                                            select_yearOld = Select(driver.find_element_by_id('yearOld'))
                                            select_yearOld.select_by_visible_text(f'{year_old_new}')
                                            
                                            select_buyYear = Select(driver.find_element_by_id('buyYear'))
                                            
                                            select_buyYear.select_by_visible_text(f'{year_mat_new}')
                                            lista_year = lista_it+[year_mat_new]
                                            
                                            time.sleep(2)
                                            
                                            driver.find_element_by_xpath('//*[@id="next"]').click()
                                            time.sleep(2)
                                            driver.find_element_by_xpath("/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-bike-usage/div/div[2]/label/div/span").click()
                                            time.sleep(2)
                                            driver.find_element_by_xpath("/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-passenger-type/div/div[3]/label/div/span").click()
                                            time.sleep(2)
                                            driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-parking-type/div/div[2]/label/div').click()
                                            time.sleep(2)
                                            kms = driver.find_element_by_xpath('//*[@id="questionContainer"]').text.split('\n')
                                            #for km in range(2,len(kms),3):
                                            for km in [6]:
                                                #lista_km = []
                                                #lista_km = lista_year+[driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-annual-km/div/div[{km}]/label/div/span').text]
                                                driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-annual-km/div/div[{km}]/label/div/span').click()
                                                time.sleep(2)
                                                                                     
                                                for year_birth in ['2002', '1999', '1995']:
                                                    driver.refresh()
                                                    time.sleep(3)
                                                    
                                                    input_day = driver.find_element_by_xpath('//*[@id="day"]')
                                                    input_day.clear()
                                                    input_day.send_keys('06')
                                                    time.sleep(2)
                                                    
                                                    select_month = Select(driver.find_element_by_xpath('//*[@id="month"]'))
                                                    select_month.select_by_visible_text('Junio')
                                                    time.sleep(2)
                                                    
                                                    input_year = driver.find_element_by_xpath('//*[@id="year"]')
                                                    input_year.clear()
                                                    input_year.send_keys(year_birth)
                                                    time.sleep(2)
                                                    lista_birth = []
                                                    lista_birth = lista_year + [2021-int(year_birth)]
                                                    #lista_birth = lista_km + [2021-int(year_birth)]
                                                    driver.find_element_by_xpath('//*[@id="next"]').click()
                                                    time.sleep(2)
                                                    driver.find_element_by_xpath("/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-birth-place/div/div/div[1]/div/label/div/div/img").click()
                                                    time.sleep(2)
                                                    #for gen in range(1,3):
                                                    for gen in [1]:
                                                        genero = driver.find_element_by_xpath(f"/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-main-driver-data/div/div[2]/div[{gen}]/div/label/div/p")
                                                        #lista_gen = []
                                                        #lista_gen = lista_birth + [genero.text]
                                                        genero.click()
                                                        time.sleep(2)
                                                        try:
                                                            driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-main-driver-data/div/div[4]/div/div[1]/label/div/span').click()
                                                        except:
                                                            pass
                                                        time.sleep(2)
                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-profession/div/div[18]/label/div/span').click()
                                                        time.sleep(2)
                                                        
                                                        #for cp in range(1,53):
                                                        for cp in [8,28]:
                                                            if cp < 10:
                                                                postcode = f'0{cp}001'
                                                            else:
                                                                postcode = f'{cp}001'
                                                            input_cp = driver.find_element_by_id("postalCode")
                                                            input_cp.clear()
                                                            input_cp.send_keys(postcode)
                                                            lista_cp = []
                                                            lista_cp = lista_birth + [str(postcode)]
                                                            time.sleep(2)
                                                        
                                                            driver.find_element_by_xpath('//*[@id="next"]').click()
                                                            time.sleep(2)
                                                            driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/app-bike-driver-childs/div/div/div/div[2]/label/div/span').click()
                                                            time.sleep(2)
                                                            
                                                            lista_c = driver.find_element_by_xpath('//*[@id="questionContainer"]').text.split('\n')[2:]
                                                            for carn in range(2,len(lista_c)+2):
                                                                
                                                                carnet = driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-licence-type/div/div[{carn}]/label/div/span')
                                                                lista_carnet = []
                                                                lista_carnet = lista_cp + [carnet.text]
                                                                
                                                                    
                                                                if carnet.text == 'B (carné de coche)':
                                                                    pass
                                                                
                                                                else:
                                                                    if year_birth == '2002':
                                                                        obt_carnet = ['2021']
                                                                    elif year_birth == '1999':
                                                                        obt_carnet = ['2021','2018']
                                                                    else:
                                                                        obt_carnet = ['2021','2018','2014']    
                                                                    
                                                                    carnet.click()
                                                                    time.sleep(2)
                                                                    
                                                                    for year_carn in obt_carnet:
                                                                        
                                                                        driver.refresh()
                                                                        time.sleep(5)
                                                                        
                                                                        select_month = Select(driver.find_element_by_xpath('//*[@id="year"]'))
                                                                        select_month.select_by_visible_text(year_carn)
                                                                        time.sleep(2)
                                                                        
                                                                        select_month = Select(driver.find_element_by_xpath('//*[@id="month"]'))
                                                                        select_month.select_by_visible_text('Julio')
                                                                        time.sleep(2)
                                                                        
                                                                        lista_obt = []
                                                                        lista_obt = lista_carnet + [int(year_carn)-int(year_birth)]
                                                                        page_input = driver.current_url
                                                                        
                                                                        driver.find_element_by_xpath('//*[@id="next"]').click()
                                                                        time.sleep(2)
                                                                        driver.refresh()
                                                                        time.sleep(3)
                                                                        
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-licence-place/div/div/div[1]/div/label/div/p').click()
                                                                        time.sleep(2)
                                                                        try:
                                                                            driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/app-last-bike/div/div/div/div[1]/label/div/span').click()
                                                                        except:
                                                                            pass
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-who-policy-holder/div/div[1]/label/div/span').click()
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/app-defaulter/div/div[2]/label/div/span').click()
                                                                        driver.refresh()
                                                                        time.sleep(5)
                                                        
                                                                        input_dni = driver.find_element_by_xpath('//*[@id="txtDniNumber"]')
                                                                        input_dni.clear()
                                                                        input_dni.send_keys('73115063H')
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('//*[@id="next"]').click()
                                                                        
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-insurer-name/div/div[1]/div/div[2]/label/div/span/font/font').click()
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/app-has-claim/div/div[2]/div/div[2]/label/div/span').click()
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-previous-fine/div/div[2]/div/div[2]/label/div/span').click()
                                                                        time.sleep(2)
                                                                        select_month = Select(driver.find_element_by_xpath('//*[@id="day"]'))
                                                                        select_month.select_by_visible_text('1')
                                                                        time.sleep(2)
                                                                        select_month = Select(driver.find_element_by_xpath('//*[@id="month"]'))
                                                                        select_month.select_by_visible_text('Septiembre')
                                                                        time.sleep(2)
                                                                        select_month = Select(driver.find_element_by_xpath('//*[@id="year"]'))
                                                                        select_month.select_by_visible_text('2021')
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('//*[@id="next"]').click()
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-kind-of-insurance/div/div[5]/label/div/span').click()
                                                                        driver.refresh()
                                                                        time.sleep(5)
                                                        
                                                                        input_mail = driver.find_element_by_xpath('//*[@id="email"]')
                                                                        input_mail.clear()
                                                                        input_mail.send_keys('xabilopez8@hotmail.com')
                                                                        time.sleep(2)
                                                                        input_phone = driver.find_element_by_xpath('//*[@id="phone"]')
                                                                        input_phone.clear()
                                                                        input_phone.send_keys('606697311')
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath("/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-email-info/div/div[3]/label/div/span[1]").click()
                                                                        
                                                                        rastreator_last = driver.current_url
                                                                        
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-email-info/app-nav-option/a[2]/font/font').click()
                                                                                                                                   
                                                                        time.sleep(30)
                                                                        while driver.current_url == 'https://presupuesto-moto.rastreator.com/resultados-comparativa/isWaitPageCounterInserted':
                                                                            time.sleep(2)
                                                                            driver.refresh()
                                                                        time.sleep(2)
                                                                        
                                                                        try:
                                                                            insur = driver.find_element_by_xpath('/html/body/app-root/div[1]/app-quote-page/div/div/div[1]/filter/div/div').text.split('\n')
                                                                            for ins in range(0,len(insur),3):
                                                                                insurance = insur[ins]
                                                                                precio = str(insur[ins+2].split('desde')[1])
                                                                                lista_ins = [] 
                                                                                lista_ins = lista_obt + [insurance] + [precio]
                                                                                bbdd_moto.append(lista_ins)
                                                                                #df = pd.DataFrame(bbdd_moto, columns = ['Marca','Modelo','Cilindrada','Versión','Potencia','Año lanzamiento','Año matriculación','Año compra','KM esperados','Edad','Género','Código postal','Tipo carnet','Años carnet','Tipo seguro','Precio mínimo'])
                                                                                df = pd.DataFrame(bbdd_moto, columns = ['Marca','Modelo','Cilindrada','Versión','Potencia','Año lanzamiento','Año matriculación','Edad actual','Código postal','Tipo carnet','Edad carnet','Tipo seguro','Precio mínimo'])
                                                                                df.to_csv('../data/dataset_honda.csv', index=False)
                                                                                print(lista_ins)
                                                                        except:
                                                                            pass
                                                                        
                                                                        while driver.current_url[:-2] != 'https://seguro-moto.rastreator.com/datos-comparativa/Q':
                                                                            driver.back()
                                                                            #time.sleep(0.5)
                                                                        driver.refresh()
                                                                        time.sleep(3)
                                                                        while driver.current_url[:-2] != 'https://seguro-moto.rastreator.com/datos-comparativa/Q':
                                                                            driver.back()
                                                                        driver.refresh()
                                                                        time.sleep(10)
                                                                        while page_input != driver.current_url:
                                                                            driver.back()
                                                                            time.sleep(3)
                                                                        driver.refresh()
                                                                        time.sleep(5)
                                                                    
                                                                    driver.back()
                                                                    time.sleep(2)
                                                            driver.back()
                                                            time.sleep(2)
                                                            driver.back()
                                                            time.sleep(2)
                           
                        
                                                        driver.back()
                                                        time.sleep(2)
                                
                        
                                                        driver.back()
                                                        time.sleep(2)
                                                    driver.back()
                                                    time.sleep(2)
                                                    driver.back()
                                                    time.sleep(2)
                                                driver.back()
                                                time.sleep(2)
                                            driver.back()
                                            time.sleep(2)
                                            driver.back()
                                            time.sleep(2)
                                            driver.back()
                                            time.sleep(2)
                                            driver.back()
                                            time.sleep(2)
                                            
                        driver.back()
                        time.sleep(2)
                        driver.back()
                        time.sleep(2)
                        pg += 1
                        k+=2
                        
                else:
                    pass
                driver.back()
                time.sleep(2)  
        else:
            pass
        driver.back()
        time.sleep(2)
    driver.back()
    time.sleep(2)
    count += 1
# Out:
# _________________________
# HONDA (1/1)
# --------------------------
# - AFRICA TWIN, 1/50
# - CB 1000, 2/50
# - CB 1100, 3/50
# - CB 125, 4/50
# - CB 300, 5/50
# - CB 500, 6/50
# - CB 650, 7/50
# - CBR 1000, 8/50
# - CBR 125, 9/50
# - CBR 250, 10/50
# - CBR 300, 11/50
# - CBR 500, 12/50
# - CBR 600, 13/50
# - CBR 650, 14/50
# - CMX 1100, 15/50
# - CMX 500, 16/50
# - CRF 110, 17/50
# - CRF 250, 18/50
# - CRF 300, 19/50
# - CRF 400, 20/50
# - CRF 450, 21/50
# - CROSSRUNNER, 22/50
# - CROSSTOURER, 23/50
# - CTX, 24/50
# - FORZA, 25/50
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '373€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '390€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '736€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '1.397€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '314€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '331€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '620€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '1.185€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '297€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '314€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '587€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '1.108€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '250€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '268€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '495€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '941€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '282€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '299€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '556€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Todo riesgo con franquicia', '1.128€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '198€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '215€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '393€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '701€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '253€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '270€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '500€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Todo riesgo con franquicia', '956€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '174€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '191€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '346€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '639€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '225€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '242€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '445€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Todo riesgo con franquicia', '896€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '159€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '176€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '316€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '560€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '203€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '220€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '401€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Todo riesgo con franquicia', '760€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '140€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '157€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '279€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '510€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '225€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '242€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '393€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Todo riesgo con franquicia', '886€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '159€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '176€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '300€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Todo riesgo con franquicia', '499€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '124€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '141€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '248€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '437€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '203€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '220€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '393€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Todo riesgo con franquicia', '801€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '144€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '161€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '287€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Todo riesgo con franquicia', '499€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '111€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '128€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '222€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '395€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '186€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '203€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '302€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Todo riesgo con franquicia', '728€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '135€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '152€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '268€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Todo riesgo con franquicia', '466€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '104€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '121€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '208€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '362€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '168€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '185€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '302€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Todo riesgo con franquicia', '659€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '120€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '137€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '240€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Todo riesgo con franquicia', '414€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '93€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '110€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '187€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2021, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '328€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '344€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '361€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '678€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '1.286€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '289€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '307€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '572€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '1.091€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '274€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '291€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '542€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '1.021€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '231€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '248€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '458€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '867€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '260€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '277€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '514€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Todo riesgo con franquicia', '1.039€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '183€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '200€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '363€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '647€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '234€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '251€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '462€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Todo riesgo con franquicia', '880€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '161€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '178€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '320€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '589€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '208€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '225€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '412€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Todo riesgo con franquicia', '826€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '147€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '164€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '293€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '517€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '187€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '204€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '371€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Todo riesgo con franquicia', '701€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '130€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '147€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '259€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '471€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '208€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '225€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '391€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Todo riesgo con franquicia', '817€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '150€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '167€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '298€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Todo riesgo con franquicia', '494€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '115€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '132€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '230€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '404€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '188€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '205€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '373€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Todo riesgo con franquicia', '739€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '134€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '151€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '266€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Todo riesgo con franquicia', '463€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '103€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '120€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '206€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '365€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '167€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '184€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '283€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Todo riesgo con franquicia', '651€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '121€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '138€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '242€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Todo riesgo con franquicia', '418€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '94€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '111€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '188€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '325€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '151€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '168€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '283€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Todo riesgo con franquicia', '589€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '108€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '125€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '216€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Todo riesgo con franquicia', '372€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '84€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '101€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '169€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '295€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '333€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '350€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '657€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '1.245€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '281€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '298€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '554€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '1.057€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '286€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '303€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '565€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '1.067€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '241€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '258€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '477€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '906€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '263€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '280€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '520€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Todo riesgo con franquicia', '1.051€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '185€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '202€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '367€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '654€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '244€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '261€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '482€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Todo riesgo con franquicia', '920€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '163€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '180€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '324€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '596€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '217€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '234€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '429€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Todo riesgo con franquicia', '863€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '153€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '171€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '305€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '539€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '195€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '212€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '387€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Todo riesgo con franquicia', '732€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '135€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '153€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '270€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '492€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '217€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '234€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '400€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Todo riesgo con franquicia', '853€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '156€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '173€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '307€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Todo riesgo con franquicia', '520€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '120€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '137€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '239€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '415€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '196€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '213€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '388€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Todo riesgo con franquicia', '771€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '139€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '156€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '277€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Todo riesgo con franquicia', '483€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '110€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '127€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '220€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '391€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '179€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '196€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '284€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Todo riesgo con franquicia', '698€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '129€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '147€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '258€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Todo riesgo con franquicia', '447€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '100€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '117€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '200€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '347€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '162€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '179€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '284€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Todo riesgo con franquicia', '632€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '115€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '133€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '231€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Todo riesgo con franquicia', '398€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '90€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '107€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '180€']
# ['HONDA', 'FORZA', '125 cc', 'FORZA 125 ABS TOPBOX', '15 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '315€']
# - GL 1800, 26/50
# - INTEGRA, 27/50
# - LEAD 125, 28/50
# - MONKEY, 29/50
# - MSX, 30/50
# - NC 700, 31/50
# - NC 750, 32/50
# - NM4 VULTUS, 33/50
# - PCX, 34/50
# - RC 213, 35/50
# - SCOOPY 125I SH, 36/50
# - SCOOPY 300I SH, 37/50
# - SCOOPY SH 125I, 38/50
# - SCOOPY SH 300I, 39/50
# - SH 125I, 40/50
# - SH 300I, 41/50
# - SH 350I, 42/50
# - SH MODE, 43/50
# - SUPER CUB, 44/50
# - SW, 45/50
# - VFR 800, 46/50
# - VISION, 47/50
# - WAVE, 48/50
# - X-ADV, 49/50
# - XRE 300, 50/50
