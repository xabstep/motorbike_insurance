# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from datetime import datetime
import time
import re
import random
import string

# %% [markdown]
# # Accessing to the website

# %%
driver = webdriver.Firefox()
driver.get('https://seguro-moto.rastreator.com/datos-comparativa/Q1')
time.sleep(5)
button_cookies = driver.find_element_by_xpath("/html/body/div[4]/div/div[2]/button[2]")
time.sleep(3)
button_cookies.click()

# %% [markdown]
# # Scrapping

# %%
bbdd_moto = []
count = 1

#list_marcas = driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-make/div/div/div/ul[1]').text.split("\n")
list_marcas = ['APRILIA']


for marca in list_marcas:  
    print(f'_________________________\n{marca} ({count}/{len(list_marcas)})\n--------------------------')
    path_marca = f'//*[@id="li_top_{marca}"]'
    button_marca = driver.find_element_by_xpath(path_marca)
    button_marca.click()
    time.sleep(2)
    list_usados = driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-model/div/div[2]/div/ul[1]').text.split("\n")
    counter = 1
    for modelo in list_usados:
        print(f'- {modelo}, {counter}/{len(list_usados)}')
        counter+=1
        button_modelo = driver.find_element_by_xpath(f'//*[@id="li_{modelo}"]')
        button_modelo.click()
        time.sleep(2)
        page = driver.current_url[-2:]
        if page == 'Q3':
            lista_cc = driver.find_element_by_xpath('//*[@id="card"]').text.split('\n')
            for j in range(3,len(lista_cc)-1):
                button_cc = driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-cubic-capacity/div/div[{j}]')
                button_cc.click()
                cilindr = int(lista_cc[j].split(' ')[0])
                time.sleep(2)
                page = driver.current_url[-2:]
                if page == 'Q4' and cilindr <= 125 and cilindr > 0:
                    modelo_lanz = driver.find_element_by_xpath('//*[@id="questionContainer"]').text.split('\n')
                    k = 1
                    pg = 1
                    while k < len(modelo_lanz) and int(modelo_lanz[k+1][-4:]) >= 2018:
                        #bbdd_moto.append([marca, modelo, lista_cc[j], modelo_lanz[k], modelo_lanz[k+1]])
                        lista_it = [marca, modelo, lista_cc[j], modelo_lanz[k], modelo_lanz[k+1].split(' | ')[1], int(modelo_lanz[k+1][-4:])]
                        time.sleep(2)
                        driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-version/div/div[{pg}]/label/div/span').click()
                        time.sleep(2)
                        driver.find_element_by_xpath("/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-already-bought/div/div[1]/label/div/span").click()
                        time.sleep(2)
                            
                        for year_old in [0]:
                            year_old_new = lista_it[5]+year_old
                            if year_old_new > 2021:
                                pass
                            else:
                                for year_mat in [0,2]:
                                    year_mat_new = lista_it[5]+year_mat
                                    if year_mat_new > 2021:
                                        pass
                                    else:
                                        if year_old>year_mat:
                                            pass
                                        else:
                                            select_monthOld = Select(driver.find_element_by_id('monthOld'))
                                            select_monthOld.select_by_visible_text('Junio')
                                            
                                            select_buyMonth = Select(driver.find_element_by_id('buyMonth'))
                                            select_buyMonth.select_by_visible_text('Junio')
                                            
                                            select_yearOld = Select(driver.find_element_by_id('yearOld'))
                                            select_yearOld.select_by_visible_text(f'{year_old_new}')
                                            
                                            select_buyYear = Select(driver.find_element_by_id('buyYear'))
                                            
                                            select_buyYear.select_by_visible_text(f'{year_mat_new}')
                                            lista_year = lista_it+[year_mat_new]
                                            
                                            time.sleep(2)
                                            
                                            driver.find_element_by_xpath('//*[@id="next"]').click()
                                            time.sleep(2)
                                            driver.find_element_by_xpath("/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-bike-usage/div/div[2]/label/div/span").click()
                                            time.sleep(2)
                                            driver.find_element_by_xpath("/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-passenger-type/div/div[3]/label/div/span").click()
                                            time.sleep(2)
                                            driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-parking-type/div/div[2]/label/div').click()
                                            time.sleep(2)
                                            kms = driver.find_element_by_xpath('//*[@id="questionContainer"]').text.split('\n')
                                            #for km in range(2,len(kms),3):
                                            for km in [6]:
                                                #lista_km = []
                                                #lista_km = lista_year+[driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-annual-km/div/div[{km}]/label/div/span').text]
                                                driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-annual-km/div/div[{km}]/label/div/span').click()
                                                time.sleep(2)
                                                                                     
                                                for year_birth in ['2002', '1999', '1995']:
                                                    driver.refresh()
                                                    time.sleep(3)
                                                    
                                                    input_day = driver.find_element_by_xpath('//*[@id="day"]')
                                                    input_day.clear()
                                                    input_day.send_keys('06')
                                                    time.sleep(2)
                                                    
                                                    select_month = Select(driver.find_element_by_xpath('//*[@id="month"]'))
                                                    select_month.select_by_visible_text('Junio')
                                                    time.sleep(2)
                                                    
                                                    input_year = driver.find_element_by_xpath('//*[@id="year"]')
                                                    input_year.clear()
                                                    input_year.send_keys(year_birth)
                                                    time.sleep(2)
                                                    lista_birth = []
                                                    lista_birth = lista_year + [2021-int(year_birth)]
                                                    #lista_birth = lista_km + [2021-int(year_birth)]
                                                    driver.find_element_by_xpath('//*[@id="next"]').click()
                                                    time.sleep(2)
                                                    driver.find_element_by_xpath("/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-birth-place/div/div/div[1]/div/label/div/div/img").click()
                                                    time.sleep(2)
                                                    #for gen in range(1,3):
                                                    for gen in [1]:
                                                        genero = driver.find_element_by_xpath(f"/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-main-driver-data/div/div[2]/div[{gen}]/div/label/div/p")
                                                        #lista_gen = []
                                                        #lista_gen = lista_birth + [genero.text]
                                                        genero.click()
                                                        time.sleep(2)
                                                        try:
                                                            driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-main-driver-data/div/div[4]/div/div[1]/label/div/span').click()
                                                        except:
                                                            pass
                                                        time.sleep(2)
                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-profession/div/div[18]/label/div/span').click()
                                                        time.sleep(2)
                                                        
                                                        #for cp in range(1,53):
                                                        for cp in [8,28]:
                                                            if cp < 10:
                                                                postcode = f'0{cp}001'
                                                            else:
                                                                postcode = f'{cp}001'
                                                            input_cp = driver.find_element_by_id("postalCode")
                                                            input_cp.clear()
                                                            input_cp.send_keys(postcode)
                                                            lista_cp = []
                                                            lista_cp = lista_birth + [str(postcode)]
                                                            time.sleep(2)
                                                        
                                                            driver.find_element_by_xpath('//*[@id="next"]').click()
                                                            time.sleep(2)
                                                            driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/app-bike-driver-childs/div/div/div/div[2]/label/div/span').click()
                                                            time.sleep(2)
                                                            
                                                            lista_c = driver.find_element_by_xpath('//*[@id="questionContainer"]').text.split('\n')[2:]
                                                            for carn in range(2,len(lista_c)+2):
                                                                
                                                                carnet = driver.find_element_by_xpath(f'/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-licence-type/div/div[{carn}]/label/div/span')
                                                                lista_carnet = []
                                                                lista_carnet = lista_cp + [carnet.text]
                                                                
                                                                    
                                                                if carnet.text == 'B (carné de coche)':
                                                                    pass
                                                                
                                                                else:
                                                                    if year_birth == '2002':
                                                                        obt_carnet = ['2021']
                                                                    elif year_birth == '1999':
                                                                        obt_carnet = ['2021','2018']
                                                                    else:
                                                                        obt_carnet = ['2021','2018','2014']    
                                                                    
                                                                    carnet.click()
                                                                    time.sleep(2)
                                                                    
                                                                    for year_carn in obt_carnet:
                                                                        
                                                                        driver.refresh()
                                                                        time.sleep(5)
                                                                        
                                                                        select_month = Select(driver.find_element_by_xpath('//*[@id="year"]'))
                                                                        select_month.select_by_visible_text(year_carn)
                                                                        time.sleep(2)
                                                                        
                                                                        select_month = Select(driver.find_element_by_xpath('//*[@id="month"]'))
                                                                        select_month.select_by_visible_text('Julio')
                                                                        time.sleep(2)
                                                                        
                                                                        lista_obt = []
                                                                        lista_obt = lista_carnet + [int(year_carn)-int(year_birth)]
                                                                        page_input = driver.current_url
                                                                        
                                                                        driver.find_element_by_xpath('//*[@id="next"]').click()
                                                                        time.sleep(2)
                                                                        driver.refresh()
                                                                        time.sleep(3)
                                                                        
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-licence-place/div/div/div[1]/div/label/div/p').click()
                                                                        time.sleep(2)
                                                                        try:
                                                                            driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/app-last-bike/div/div/div/div[1]/label/div/span').click()
                                                                        except:
                                                                            pass
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-who-policy-holder/div/div[1]/label/div/span').click()
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/app-defaulter/div/div[2]/label/div/span').click()
                                                                        driver.refresh()
                                                                        time.sleep(5)
                                                        
                                                                        input_dni = driver.find_element_by_xpath('//*[@id="txtDniNumber"]')
                                                                        input_dni.clear()
                                                                        input_dni.send_keys('73115063H')
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('//*[@id="next"]').click()
                                                                        
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-insurer-name/div/div[1]/div/div[2]/label/div/span/font/font').click()
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/app-has-claim/div/div[2]/div/div[2]/label/div/span').click()
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-previous-fine/div/div[2]/div/div[2]/label/div/span').click()
                                                                        time.sleep(2)
                                                                        select_month = Select(driver.find_element_by_xpath('//*[@id="day"]'))
                                                                        select_month.select_by_visible_text('1')
                                                                        time.sleep(2)
                                                                        select_month = Select(driver.find_element_by_xpath('//*[@id="month"]'))
                                                                        select_month.select_by_visible_text('Septiembre')
                                                                        time.sleep(2)
                                                                        select_month = Select(driver.find_element_by_xpath('//*[@id="year"]'))
                                                                        select_month.select_by_visible_text('2021')
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('//*[@id="next"]').click()
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-kind-of-insurance/div/div[5]/label/div/span').click()
                                                                        driver.refresh()
                                                                        time.sleep(5)
                                                        
                                                                        input_mail = driver.find_element_by_xpath('//*[@id="email"]')
                                                                        input_mail.clear()
                                                                        input_mail.send_keys('xabilopez8@hotmail.com')
                                                                        time.sleep(2)
                                                                        input_phone = driver.find_element_by_xpath('//*[@id="phone"]')
                                                                        input_phone.clear()
                                                                        input_phone.send_keys('606697311')
                                                                        time.sleep(2)
                                                                        driver.find_element_by_xpath("/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-email-info/div/div[3]/label/div/span[1]").click()
                                                                        
                                                                        rastreator_last = driver.current_url
                                                                        
                                                                        driver.find_element_by_xpath('/html/body/app-root/app-single-question/div[3]/div/div/div/div/div/cj-process-email-info/app-nav-option/a[2]/font/font').click()
                                                                                                                                   
                                                                        time.sleep(30)
                                                                        while driver.current_url == 'https://presupuesto-moto.rastreator.com/resultados-comparativa/isWaitPageCounterInserted':
                                                                            time.sleep(2)
                                                                            driver.refresh()
                                                                        time.sleep(2)
                                                                        
                                                                        try:
                                                                            insur = driver.find_element_by_xpath('/html/body/app-root/div[1]/app-quote-page/div/div/div[1]/filter/div/div').text.split('\n')
                                                                            for ins in range(0,len(insur),3):
                                                                                insurance = insur[ins]
                                                                                precio = str(insur[ins+2].split('desde')[1])
                                                                                lista_ins = [] 
                                                                                lista_ins = lista_obt + [insurance] + [precio]
                                                                                bbdd_moto.append(lista_ins)
                                                                                #df = pd.DataFrame(bbdd_moto, columns = ['Marca','Modelo','Cilindrada','Versión','Potencia','Año lanzamiento','Año matriculación','Año compra','KM esperados','Edad','Género','Código postal','Tipo carnet','Años carnet','Tipo seguro','Precio mínimo'])
                                                                                df = pd.DataFrame(bbdd_moto, columns = ['Marca','Modelo','Cilindrada','Versión','Potencia','Año lanzamiento','Año matriculación','Edad actual','Código postal','Tipo carnet','Edad carnet','Tipo seguro','Precio mínimo'])
                                                                                df.to_csv('../data/dataset_aprilia.csv', index=False)
                                                                                print(lista_ins)
                                                                        except:
                                                                            pass
                                                                        
                                                                        while driver.current_url[:-2] != 'https://seguro-moto.rastreator.com/datos-comparativa/Q':
                                                                            driver.back()
                                                                            #time.sleep(0.5)
                                                                        driver.refresh()
                                                                        time.sleep(3)
                                                                        while driver.current_url[:-2] != 'https://seguro-moto.rastreator.com/datos-comparativa/Q':
                                                                            driver.back()
                                                                        driver.refresh()
                                                                        time.sleep(10)
                                                                        while page_input != driver.current_url:
                                                                            driver.back()
                                                                            time.sleep(3)
                                                                        driver.refresh()
                                                                        time.sleep(5)
                                                                    
                                                                    driver.back()
                                                                    time.sleep(2)
                                                            driver.back()
                                                            time.sleep(2)
                                                            driver.back()
                                                            time.sleep(2)
                           
                        
                                                        driver.back()
                                                        time.sleep(2)
                                
                        
                                                        driver.back()
                                                        time.sleep(2)
                                                    driver.back()
                                                    time.sleep(2)
                                                    driver.back()
                                                    time.sleep(2)
                                                driver.back()
                                                time.sleep(2)
                                            driver.back()
                                            time.sleep(2)
                                            driver.back()
                                            time.sleep(2)
                                            driver.back()
                                            time.sleep(2)
                                            driver.back()
                                            time.sleep(2)
                                            
                        driver.back()
                        time.sleep(2)
                        driver.back()
                        time.sleep(2)
                        pg += 1
                        k+=2
                        
                else:
                    pass
                driver.back()
                time.sleep(2)  
        else:
            pass
        driver.back()
        time.sleep(2)
    driver.back()
    time.sleep(2)
    count += 1
# Out:
# _________________________
# APRILIA (1/1)
# --------------------------
# - DORSODURO, 1/18
# - ETV 1200, 2/18
# - RS, 3/18
# - RS4, 4/18
# - RSV4 1000, 5/18
# - RSV4 1100, 6/18
# - RX, 7/18
# - RX 125, 8/18
# - SCARABEO 50, 9/18
# - SHIVER, 10/18
# - SMV, 11/18
# - SR 125, 12/18
# - SR 50, 13/18
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '423€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '440€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '1.340€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '356€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '372€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '1.340€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 19, '08001', 'Licencia de ciclomotor', 19, 'Terceros sin asistencia en viaje', '428€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 19, '08001', 'Licencia de ciclomotor', 19, 'Terceros con asistencia en viaje', '445€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '337€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '353€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '1.152€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '283€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '300€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '1.152€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 19, '28001', 'Licencia de ciclomotor', 19, 'Terceros sin asistencia en viaje', '341€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 19, '28001', 'Licencia de ciclomotor', 19, 'Terceros con asistencia en viaje', '357€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '319€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '335€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '1.340€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '223€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '240€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '790€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '286€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '303€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '1.340€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '196€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '213€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '790€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '08001', 'Licencia de ciclomotor', 22, 'Terceros sin asistencia en viaje', '382€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '08001', 'Licencia de ciclomotor', 22, 'Terceros con asistencia en viaje', '398€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '08001', 'Licencia de ciclomotor', 19, 'Terceros sin asistencia en viaje', '259€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '08001', 'Licencia de ciclomotor', 19, 'Terceros con asistencia en viaje', '275€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '254€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '271€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '1.152€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '179€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '195€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '671€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '228€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '245€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '1.152€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '157€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '174€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '671€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '28001', 'Licencia de ciclomotor', 22, 'Terceros sin asistencia en viaje', '304€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '28001', 'Licencia de ciclomotor', 22, 'Terceros con asistencia en viaje', '320€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '28001', 'Licencia de ciclomotor', 19, 'Terceros sin asistencia en viaje', '207€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 22, '28001', 'Licencia de ciclomotor', 19, 'Terceros con asistencia en viaje', '223€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '134€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '271€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '851€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '134€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '199€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '519€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '134€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '156€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '443€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '134€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '246€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '851€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '134€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '178€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '519€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '124€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '141€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '443€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'Licencia de ciclomotor', 26, 'Terceros sin asistencia en viaje', '162€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'Licencia de ciclomotor', 26, 'Terceros con asistencia en viaje', '330€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'Licencia de ciclomotor', 23, 'Terceros sin asistencia en viaje', '162€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'Licencia de ciclomotor', 23, 'Terceros con asistencia en viaje', '241€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'Licencia de ciclomotor', 19, 'Terceros sin asistencia en viaje', '162€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '08001', 'Licencia de ciclomotor', 19, 'Terceros con asistencia en viaje', '187€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '163€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '220€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '723€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '112€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '129€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '367€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '163€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '200€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '723€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '130€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '147€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '433€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '100€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '117€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '367€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'Licencia de ciclomotor', 26, 'Terceros sin asistencia en viaje', '197€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'Licencia de ciclomotor', 26, 'Terceros con asistencia en viaje', '267€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'Licencia de ciclomotor', 23, 'Terceros sin asistencia en viaje', '180€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'Licencia de ciclomotor', 23, 'Terceros con asistencia en viaje', '196€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'Licencia de ciclomotor', 19, 'Terceros sin asistencia en viaje', '137€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2019, 26, '28001', 'Licencia de ciclomotor', 19, 'Terceros con asistencia en viaje', '154€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '435€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '452€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '1.340€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '366€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '382€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '1.340€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 19, '08001', 'Licencia de ciclomotor', 19, 'Terceros sin asistencia en viaje', '441€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 19, '08001', 'Licencia de ciclomotor', 19, 'Terceros con asistencia en viaje', '457€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '346€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '363€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '1.152€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '291€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '308€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '1.152€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 19, '28001', 'Licencia de ciclomotor', 19, 'Terceros sin asistencia en viaje', '350€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 19, '28001', 'Licencia de ciclomotor', 19, 'Terceros con asistencia en viaje', '367€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '328€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '344€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '1.340€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '230€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '246€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '825€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '294€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '311€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '1.340€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '202€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '218€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '825€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '08001', 'Licencia de ciclomotor', 22, 'Terceros sin asistencia en viaje', '393€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '08001', 'Licencia de ciclomotor', 22, 'Terceros con asistencia en viaje', '409€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '08001', 'Licencia de ciclomotor', 19, 'Terceros sin asistencia en viaje', '266€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '08001', 'Licencia de ciclomotor', 19, 'Terceros con asistencia en viaje', '283€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '261€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '278€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '1.152€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '184€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '200€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '701€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '235€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '251€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '1.152€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '162€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '178€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '701€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '28001', 'Licencia de ciclomotor', 22, 'Terceros sin asistencia en viaje', '312€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '28001', 'Licencia de ciclomotor', 22, 'Terceros con asistencia en viaje', '329€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '28001', 'Licencia de ciclomotor', 19, 'Terceros sin asistencia en viaje', '213€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 22, '28001', 'Licencia de ciclomotor', 19, 'Terceros con asistencia en viaje', '229€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '134€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '278€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '851€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '134€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '204€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '540€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '134€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '159€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '461€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '134€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '252€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '851€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '134€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '183€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '540€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '127€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '144€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '461€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'Licencia de ciclomotor', 26, 'Terceros sin asistencia en viaje', '162€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'Licencia de ciclomotor', 26, 'Terceros con asistencia en viaje', '339€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'Licencia de ciclomotor', 23, 'Terceros sin asistencia en viaje', '162€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'Licencia de ciclomotor', 23, 'Terceros con asistencia en viaje', '247€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'Licencia de ciclomotor', 19, 'Terceros sin asistencia en viaje', '162€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '08001', 'Licencia de ciclomotor', 19, 'Terceros con asistencia en viaje', '192€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '163€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '226€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '723€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '150€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '167€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '452€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '115€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '132€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '382€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '163€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '205€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '723€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '134€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '150€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '452€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '103€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '120€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '382€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'Licencia de ciclomotor', 26, 'Terceros sin asistencia en viaje', '197€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'Licencia de ciclomotor', 26, 'Terceros con asistencia en viaje', '274€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'Licencia de ciclomotor', 23, 'Terceros sin asistencia en viaje', '184€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'Licencia de ciclomotor', 23, 'Terceros con asistencia en viaje', '201€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'Licencia de ciclomotor', 19, 'Terceros sin asistencia en viaje', '197€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 MOTARD', '4 CV', 2019, 2021, 26, '28001', 'Licencia de ciclomotor', 19, 'Terceros con asistencia en viaje', '278€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '419€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '436€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 19, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '1.352€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '352€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '369€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '1.352€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 19, '08001', 'Licencia de ciclomotor', 19, 'Terceros sin asistencia en viaje', '424€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 19, '08001', 'Licencia de ciclomotor', 19, 'Terceros con asistencia en viaje', '441€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '333€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '350€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 19, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '1.158€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '281€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '297€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '1.158€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 19, '28001', 'Licencia de ciclomotor', 19, 'Terceros sin asistencia en viaje', '337€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 19, '28001', 'Licencia de ciclomotor', 19, 'Terceros con asistencia en viaje', '354€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '316€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '332€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '1.352€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '221€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '238€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '775€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '284€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '300€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '1.352€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '194€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '211€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '775€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '08001', 'Licencia de ciclomotor', 22, 'Terceros sin asistencia en viaje', '378€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '08001', 'Licencia de ciclomotor', 22, 'Terceros con asistencia en viaje', '395€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '08001', 'Licencia de ciclomotor', 19, 'Terceros sin asistencia en viaje', '256€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '08001', 'Licencia de ciclomotor', 19, 'Terceros con asistencia en viaje', '273€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '252€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '268€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '1.158€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '177€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '194€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '653€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '226€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '243€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '1.158€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '156€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '173€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '653€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '28001', 'Licencia de ciclomotor', 22, 'Terceros sin asistencia en viaje', '301€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '28001', 'Licencia de ciclomotor', 22, 'Terceros con asistencia en viaje', '317€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '28001', 'Licencia de ciclomotor', 19, 'Terceros sin asistencia en viaje', '205€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 22, '28001', 'Licencia de ciclomotor', 19, 'Terceros con asistencia en viaje', '221€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '134€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '269€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '863€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '134€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '197€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '515€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '134€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '154€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '442€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '134€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '244€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '863€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '134€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '177€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '515€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '123€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '139€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '442€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'Licencia de ciclomotor', 26, 'Terceros sin asistencia en viaje', '162€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'Licencia de ciclomotor', 26, 'Terceros con asistencia en viaje', '327€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'Licencia de ciclomotor', 23, 'Terceros sin asistencia en viaje', '162€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'Licencia de ciclomotor', 23, 'Terceros con asistencia en viaje', '239€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'Licencia de ciclomotor', 19, 'Terceros sin asistencia en viaje', '162€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '08001', 'Licencia de ciclomotor', 19, 'Terceros con asistencia en viaje', '186€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '163€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '218€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '730€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '145€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '162€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '425€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '111€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '128€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '362€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '163€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '199€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '730€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '129€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '146€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '425€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '100€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '116€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '362€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'Licencia de ciclomotor', 26, 'Terceros sin asistencia en viaje', '197€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'Licencia de ciclomotor', 26, 'Terceros con asistencia en viaje', '264€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'Licencia de ciclomotor', 23, 'Terceros sin asistencia en viaje', '178€']
# ['APRILIA', 'SR 50', '50 cc', 'SR 50 R', '4 CV', 2018, 2018, 26, '28001', 'Licencia de ciclomotor', 23, 'Terceros con asistencia en viaje', '194€']
# ...
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '423€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '440€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '796€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 19, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '1.519€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '337€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '354€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '635€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 19, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '1.205€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '379€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '396€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '714€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Todo riesgo con franquicia', '1.446€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '265€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '282€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '501€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '896€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '340€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '357€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '641€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Todo riesgo con franquicia', '1.224€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '233€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '250€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '440€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '815€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros sin asistencia en viaje', '302€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros con asistencia en viaje', '319€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Terceros ampliado', '570€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 22, 'Todo riesgo con franquicia', '1.147€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '212€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '229€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '402€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '713€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros sin asistencia en viaje', '271€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros con asistencia en viaje', '288€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Terceros ampliado', '512€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 22, 'Todo riesgo con franquicia', '972€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '187€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '204€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '354€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 22, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '649€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '299€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '316€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '502€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Todo riesgo con franquicia', '1.119€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '215€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '232€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '406€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Todo riesgo con franquicia', '664€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '142€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '181€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '229€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '332€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '270€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '288€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '511€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Todo riesgo con franquicia', '1.017€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '190€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '207€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '361€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Todo riesgo con franquicia', '633€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '146€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '163€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '277€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '08001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '497€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros sin asistencia en viaje', '218€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros con asistencia en viaje', '264€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Terceros ampliado', '319€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 26, 'Todo riesgo con franquicia', '923€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros sin asistencia en viaje', '178€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros con asistencia en viaje', '195€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Terceros ampliado', '291€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 23, 'Todo riesgo con franquicia', '588€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros sin asistencia en viaje', '129€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros con asistencia en viaje', '153€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Terceros ampliado', '215€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A1 (para conducir motos de hasta 125cc)', 19, 'Todo riesgo con franquicia', '317€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros sin asistencia en viaje', '223€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros con asistencia en viaje', '240€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Terceros ampliado', '411€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 26, 'Todo riesgo con franquicia', '835€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros sin asistencia en viaje', '158€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros con asistencia en viaje', '175€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Terceros ampliado', '300€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 23, 'Todo riesgo con franquicia', '521€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros sin asistencia en viaje', '121€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros con asistencia en viaje', '138€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Terceros ampliado', '232€']
# ['APRILIA', 'TUONO', '124 cc', 'TUONO 125 V4 ABS', '14 CV', 2020, 2020, 26, '28001', 'A2 (para motos de hasta 35kw y 0,2 kw/kg o motos limitadas)', 19, 'Todo riesgo con franquicia', '411€']
